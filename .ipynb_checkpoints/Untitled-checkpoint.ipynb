# %%
# %matplotlib inline

# %%
import pandas
import datetime
import pytz
import os
import time
import mysql.connector as mysql
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Get current date
#     We need to convert time from timezone EET to US/Eastern

# %%
def get_curr_date():
    my_timestamp = datetime.datetime.now()

    old_timezone = pytz.timezone("EET")
    new_timezone = pytz.timezone("US/Eastern")

    localized_timestamp = old_timezone.localize(my_timestamp)
    new_timezone_timestamp = localized_timestamp.astimezone(new_timezone)

    return new_timezone_timestamp.strftime("%Y, %-m, %-d, %-H, %-M")

# %% [markdown]
# ### Convert data form list to dataframe
#     Pandas Dataframe has more attributes than normal python list

# %%
def convert_to_dataframe(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'dividends', 'stocksplits']):
    df = pandas.DataFrame(data)
    df.transpose()

    df.columns = columns
    return df

# %% [markdown]
# ### Calculate rsi
#
# ##### The Formula for RSI.
#   The relative strength index (RSI) is computed with a
#      two-part calculation that starts with the following formula:

# %% [markdown]
# First Step Equation
# $$ RSI_{step\space one} = 100 - \left[ \frac{100}{1 + \frac{Avg\space gain}{Avg\space loss}}\right] $$
#
# The average gain or loss used in the calculation is the average percentage
# gain or loss during a look-back period. The formula uses a positive value for the average loss.
#
# The standard is to use 14 periods to calculate the initial RSI value. For example, imagine the market closed higher seven out of the past 14 days with an average gain of 1%. The remaining seven days all closed lower with an average loss of -0.8%. The calculation for the first part of the RSI would look like the following expanded calculation:
#
# $$ 55.55 = 100 - \left[ \frac{100}{1 + \frac{\frac{1\%}{14}}{\frac{-0.8\%}{14}}}\right] $$
#
# Once there are 14 periods of data available, the second part of the RSI formula can be calculated. The second step of the calculation smooths the results.
#
# Second Step Equation
# $$ RSI_{step\space two} = 100 - \left[ \frac{100}{1 + \frac{−((Previous\space Average\space Loss×13) \space +
# \space Current \space Loss)}{(Previous \space Average \space Gain×13) \space + \space Current \space Gain}} \right]$$

# %%
def calculate_rsi(dataframe, window_length=14):
    close = dataframe['close']
    delta = close.diff()
    # Get rid of the first row, which is NaN
    delta = delta[1:] 
    #print(delta)
    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0
#     # Calculate the EWMA
#     roll_up1 = up.ewm(span=window_length).mean()
#     roll_down1 = down.abs().ewm(span=window_length).mean()
#     # Calculate the RSI based on EWMA
#     RS1 = roll_up1 / roll_down1
#     RSI1 = 100.0 - (100.0 / (1.0 + RS1))
    
    
    # Calculate the SMA
    roll_up2 = up.rolling(window_length).mean()
    roll_down2 = down.abs().rolling(window_length).mean()
    # Calculate the RSI based on SMA
    RS2 = roll_up2 / roll_down2
    RSI2 = 100.0 - (100.0 / (1.0 + RS2))
    
    return RSI2

# %% [markdown]
# ### Add SMA and EMA to dataframe

# %% [markdown]
# #### Calculate SMA
#
# The SMA is easy to calculate and is the average stock price over a certain period based on a set of parameters. The moving average is calculated by adding a stock's prices over a certain period and dividing the sum by the total number of periods.
#
# SMA equation:
# $$ SMA = \frac{\left(price_0 + \cdots + price_n \right)}{n} $$
#
# For example, a trader wants to calculate the SMA for stock ABC by looking at the high of day over five periods. For the past five days, the highs of the day were $25.40, $25.90. $26.50, $26.30 and $27.90. The SMA, based on the highs, is $26.40.
# $$ $26.4 = \frac{\left($25.40+$25.90+$26.50+$26.30+$27.90\right)}{5}$$

# %%
def add_two_moving_averages(df, first_period: int, second_period: int, moving_average_template: str):
    if first_period > 0 and second_period > 0:
        df[moving_average_template+str(first_period)] = df['close'].rolling(window=first_period).mean()
        df[moving_average_template+str(second_period)] = df['close'].rolling(window=second_period).mean()
    else:
        print("Periods for moving averages have to be more than 0")

# %% [markdown]
# #### Calculate EMA
#
# An exponential moving average (EMA) is a type of moving average (MA) that places a greater weight and significance on the most recent data points. The exponential moving average is also referred to as the exponentially weighted moving average. An exponentially weighted moving average reacts more significantly to recent price changes than a simple moving average (SMA), which applies an equal weight to all observations in the period.
#
# EMA equation:
#
# EMAToday​=​(ValueToday​∗(1+Days
# Smoothing​))+EMAYesterday​∗(1−(1+Days
# Smoothing​))​
#
#
# $$ EMA_{today} = \left(Value_{today} * \frac{Smoothing}{1 + Days} \right) + \left( EMA_{Yesterday} * \left( 1 -  \frac{Smoothing}{1 + Days}\right) \right)$$
#
#
#
# * Legend
#    1. Smoothing - commonly equals to 2

# %%
def add_two_exponential_moving_averages(df, first_period: int, second_period: int, moving_average_template: str):
    if first_period > 0 and second_period > 0:
        df[moving_average_template+str(first_period)] = df['close'].ewm(span = first_period, adjust = False).mean()
        df[moving_average_template+str(second_period)] = df['close'].ewm(span = second_period, adjust = False).mean()
    else:
        print("Periods for moving averages have to be more than 0")

# %% [markdown]
# ### Get data from database

# %%
def get_database_data(): 
    db = mysql.connect(
    host = "localhost",
    user = "root",
    passwd = "Asdf123er!",
    auth_plugin='mysql_native_password',
    database = "borader"
    )

    cursor = db.cursor()

    query = "Select * from myFinalTable"

    cursor.execute(query)
    data = cursor.fetchall()
    return data

# %%
# Transforming data(list) to dataframe
# Dataframe has more options for making trading strategies
df = convert_to_dataframe(get_database_data())

def make_buy_sell_strategy(df, strategy_label_one, strategy_label_two):
    #TODO Exeption if strategy_labels aren't matching
    
    df['signal'] = 0.0  
    df['signal'] = np.where(df[strategy_label_one] > df[strategy_label_two], 1.0, 0.0) 

    # Get the difference between element-to element
    # That way you can track when xMA is crossing yMA
    # When xMA pass over yMA - buy
    # When xMA pass under yMA - sell
    df['position'] = df['signal'].diff()

    
def close_position(money, close_price, open_price, rsi, bought_or_sold):
    if bought_or_sold:
        money += close_price
        print(f"Closed position at price level: {close_price}! Price range: {close_price - open_price}, RSI: {rsi}")
    else:
        money -= close_price * 1.01
        print(f"Closed position at price level: {close_price}! Price range: {open_price - close_price}, RSI: {rsi}")
    
    return [money, False]


def open_position(money, close_price, bought_or_sold):
    if bought_or_sold:
        money -= int(close_price * 1.01)
    else:
        money += close_price
    
    return [money, close_price, True]
    
    
def print_results_from_strategy(df, start_index, ticker):
    # This is dumb but for now works
    result = []
    is_stock_bought = False
    price_bought = 0
    is_stock_sold = False
    price_sold = 0
    won = 0
    close_price = 0
    wait_for_buy_10_minutes = -1
    wait_for_sell_10_minutes = -1
    money = 1000
    print(f"Starting with {money}.")
    for i in range(start_index, len(df)):
        close_price = df.loc[i]['close']
        if df.loc[i]['position'] == 1:
            wait_for_buy_10_minutes = 18
            wait_for_sell_10_minutes = -1
            
        elif df.loc[i]['position'] == -1:
            wait_for_sell_10_minutes = 18
            wait_for_buy_10_minutes = -1
            
        if wait_for_buy_10_minutes == 0:
            if is_stock_sold:
                money, is_stock_sold = close_position(money, close_price, price_sold, df.loc[i]['rsi'], False)
                result.append([i, df.loc[i]['close']])
                
            if not is_stock_bought:
                print(f"Bought {ticker} possition when price level: {close_price}, RSI: {df.loc[i]['rsi']}")
                result.append([i, df.loc[i]['close']])
                money, price_bought, is_stock_bought = open_position(money, close_price, True)
                
        if wait_for_sell_10_minutes == 0:
            if is_stock_bought:
                money, is_stock_bought = close_position(money, close_price, price_bought, df.loc[i]['rsi'], True)
                result.append([i, df.loc[i]['close']])
                
            if not is_stock_sold:
                print(f"Sold {ticker} position when price level: {close_price}, RSI: {df.loc[i]['rsi']}")
                result.append([i, df.loc[i]['close']])
                money, price_sold, is_stock_sold = open_position(money, close_price, False)
                
                print(f"Current money {money}")
        wait_for_buy_10_minutes -= 1
        wait_for_sell_10_minutes -= 1

                
    if is_stock_sold:
        money, is_stock_sold = close_position(money, close_price, price_sold, df.loc[i]['rsi'], False)
    
    if is_stock_bought:
        money, is_stock_bought = close_position(money, close_price, price_bought, df.loc[i]['rsi'], True)
        
    print(f"End up with {money}!!!")
    
    return result


def print_results_from_strategy_2(df, start_index, ma, ticker):
    # This is dumb but for now works
    result = []
    is_stock_bought = False
    price_bought = 0
    is_stock_sold = False
    price_sold = 0
    won = 0
    close_price = 0
    money = 1000
    print(f"Starting with {money}.")
    for i in range(start_index, len(df)):
        close_price = df.loc[i]['close']
        sma = df.loc[i][ma]
        if close_price * 1.009 <= sma:
            if is_stock_bought:
                money, is_stock_bought = close_position(money, close_price, price_bought, df.loc[i]['rsi'], True)
                result.append([i, df.loc[i]['close']])
                
            if not is_stock_sold:
                print(f"Sold {ticker} position when price level: {close_price}, RSI: {df.loc[i]['rsi']}")
                result.append([i, df.loc[i]['close']])
                money, price_sold, is_stock_sold = open_position(money, close_price, False)
                
                print(f"Current money {money}")
            
        elif close_price * 0.991 >= sma:
            if is_stock_sold:
                money, is_stock_sold = close_position(money, close_price, price_sold, df.loc[i]['rsi'], False)
                result.append([i, df.loc[i]['close']])
                
            if not is_stock_bought:
                print(f"Bought {ticker} possition when price level: {close_price}, RSI: {df.loc[i]['rsi']}")
                result.append([i, df.loc[i]['close']])
                money, price_bought, is_stock_bought = open_position(money, close_price, True)

                
    if is_stock_sold:
        money, is_stock_sold = close_position(money, close_price, price_sold, df.loc[i]['rsi'], False)
    
    if is_stock_bought:
        money, is_stock_bought = close_position(money, close_price, price_bought, df.loc[i]['rsi'], True)
        
    print(f"End up with {money}!!!")
    
    return result


period_one = 80 # 30 for the win - EMA: 50 for the win 
period_two = 180 # 60 for the win - EMA: 200 for the win
"""moving_average_template = "SMA"
add_two_moving_averages(df, period_one, period_two, moving_average_template)

ma_one = moving_average_template+str(period_one)
ma_two = moving_average_template+str(period_two)

get_buy_sell_decision(df, ma_one, ma_two)"""

moving_average_template = "EMA"
add_two_exponential_moving_averages(df, period_one, period_two, moving_average_template)
ma_one = moving_average_template+str(period_one)
ma_two = moving_average_template+str(period_two)

make_buy_sell_strategy(df, ma_one, ma_two)
df1 = calculate_rsi(df)
res = []
for d in df1:
    res.append(d)
    
df['rsi'] = convert_to_dataframe(res, columns=['rsi'])
start_index = 50
#res = print_results_from_strategy(df, start_index, "Tesla")
print(df.loc[130]["EMA50"])
print(df.loc[130]["close"])
res = print_results_from_strategy_2(df, start_index, "EMA50", "Tesla")
    
    
plt.figure(figsize=(10,10))
plt.tick_params(axis = 'both', labelsize = 10)
plt.plot(df.loc[start_index:]['close'], label="close")
"""plt.plot(df.loc[900:][ma_label_one], 'g--', label=ma_label_one)
plt.plot(df.loc[900:][ma_label_two], 'r--', label=ma_label_two)"""

# After visualizing ma and ema :
# Results: EMA is more accurate and will potentially win more money
plt.plot(df.loc[start_index:][ma_one], 'y--', label=ma_one)
plt.plot(df.loc[start_index:][ma_two], 'b--', label=ma_two)

# Plot buy signals
plt.plot(df.loc[start_index:][df.loc[start_index:]['position'] == 1].index, 
         df.loc[start_index:][ma_one][df.loc[start_index:]['position'] == 1], 
         '.', markersize = 10, color = 'g', label = 'buy')
# Plot sell signals
plt.plot(df.loc[start_index:][df.loc[start_index:]['position'] == -1].index, 
         df.loc[start_index:][ma_one][df.loc[start_index:]['position'] == -1], 
         '.', markersize = 10, color = 'r', label = 'sell')

np1 = np.array([i[0] for i in res])
np2 = np.array([i[1] for i in res])
plt.plot(np1, np2, ".", color='black')
plt.legend()
plt.xlabel("date")
plt.ylabel("$ price")
plt.grid()
plt.show()

df.drop(ma_one, axis=1, inplace=True)
df.drop(ma_two, axis=1, inplace=True)

# TODO if stock breaks down
# Out:
# 671.8015675060116
# 667.3699951171875
# Starting with 1000.
# Sold Tesla position when price level: 684.0, RSI: 29.785883563624623
# Current money 1684.0
# Closed position at price level: 636.77001953125! Price range: 47.22998046875, RSI: 64.20185245616481
# Bought Tesla possition when price level: 636.77001953125, RSI: 64.20185245616481
# Closed position at price level: 624.6849975585938! Price range: -12.08502197265625, RSI: 33.62719732895253
# Sold Tesla position when price level: 624.6849975585938, RSI: 33.62719732895253
# Current money 1647.232275390625
# Closed position at price level: 638.2999877929688! Price range: -13.614990234375, RSI: 64.39659845818824
# Bought Tesla possition when price level: 638.2999877929688, RSI: 64.39659845818824
# Closed position at price level: 628.3300170898438! Price range: -9.969970703125, RSI: 32.369965103862796
# Sold Tesla position when price level: 628.3300170898438, RSI: 32.369965103862796
# Current money 1615.2093218994141
# Closed position at price level: 612.580078125! Price range: 15.74993896484375, RSI: 57.82180990514324
# Bought Tesla possition when price level: 612.580078125, RSI: 57.82180990514324
# Closed position at price level: 596.719970703125! Price range: -15.860107421875, RSI: 35.54888252809667
# Sold Tesla position when price level: 596.719970703125, RSI: 35.54888252809667
# Current money 1571.9433843994143
# Closed position at price level: 614.7800903320312! Price range: -18.06011962890625, RSI: 69.3827038737889
# Bought Tesla possition when price level: 614.7800903320312, RSI: 69.3827038737889
# Closed position at price level: 666.7459716796875! Price range: 51.96588134765625, RSI: 27.343962165420308
# Sold Tesla position when price level: 666.7459716796875, RSI: 27.343962165420308
# Current money 1664.5074365234377
# Closed position at price level: 703.6900024414062! Price range: -36.94403076171875, RSI: 75.20927586487146
# Bought Tesla possition when price level: 703.6900024414062, RSI: 75.20927586487146
# Closed position at price level: 686.7399291992188! Price range: -16.9500732421875, RSI: 13.33754423428114
# Sold Tesla position when price level: 686.7399291992188, RSI: 13.33754423428114
# Current money 1617.260392456055
# Closed position at price level: 683.6466064453125! Price range: 3.09332275390625, RSI: 81.51380037317954
# Bought Tesla possition when price level: 683.6466064453125, RSI: 81.51380037317954
# Closed position at price level: 674.72998046875! Price range: -8.9166259765625, RSI: 35.37834246960101
# Sold Tesla position when price level: 674.72998046875, RSI: 35.37834246960101
# Current money 1586.2372808837893
# Closed position at price level: 683.7150268554688! Price range: -8.98504638671875, RSI: 82.42172417171409
# Bought Tesla possition when price level: 683.7150268554688, RSI: 82.42172417171409
# Closed position at price level: 746.1900024414062! Price range: 62.4749755859375, RSI: 22.235958969163562
# Sold Tesla position when price level: 746.1900024414062, RSI: 22.235958969163562
# Current money 1698.0651086425783
# Closed position at price level: 762.717529296875! Price range: -16.52752685546875, RSI: 71.79081734151228
# Bought Tesla possition when price level: 762.717529296875, RSI: 71.79081734151228
# Closed position at price level: 745.3189697265625! Price range: -17.3985595703125, RSI: 25.979805379442112
# Sold Tesla position when price level: 745.3189697265625, RSI: 25.979805379442112
# Current money 1648.3583435058595
# Closed position at price level: 744.77001953125! Price range: 0.5489501953125, RSI: 95.33564287233719
# Bought Tesla possition when price level: 744.77001953125, RSI: 95.33564287233719
# Closed position at price level: 719.1099853515625! Price range: -25.6600341796875, RSI: 10.705505716343993
# Sold Tesla position when price level: 719.1099853515625, RSI: 10.705505716343993
# Current money 1582.3605944824221
# Closed position at price level: 722.1400146484375! Price range: -3.030029296875, RSI: 81.09729107075832
# Bought Tesla possition when price level: 722.1400146484375, RSI: 81.09729107075832
# Closed position at price level: 704.989990234375! Price range: -17.1500244140625, RSI: 24.3965880469284
# Sold Tesla position when price level: 704.989990234375, RSI: 24.3965880469284
# Current money 1533.9791601562501
# Closed position at price level: 723.0999755859375! Price range: -18.1099853515625, RSI: 81.21820109024833
# Bought Tesla possition when price level: 723.0999755859375, RSI: 81.21820109024833
# Closed position at price level: 743.9099731445312! Price range: 20.80999755859375, RSI: nan
# End up with 817.5581579589846!!!

# %%
# print(df)
# plt.figure(figsize=(10,10))
# plt.plot(calculate_rsi(df))
# plt.show()
def print_rsi_strategy(df, start_index=14):
    result = []
    is_stock_bought = False
    price_bought = 0
    is_stock_sold = False
    price_sold = 0
    won = 0
    close_price = 0
    money = 1000
    print(f"Starting with {money}.")
    for i in range(start_index, len(df) - 1):
        close_price = df.loc[i]['close']
        if df.loc[i]['rsi'] >= 60 and df.loc[i]['rsi'] <= 70:
            if not is_stock_bought:
                print(f"Bought Tesla possition when price level: {close_price} and RSI: {df.loc[i]['rsi']}")
                money -= int(close_price * 1.01)
                price_bought = close_price
                is_stock_bought = True
                result.append([i, df.loc[i]['close']])
                print(f"Current money {money}")
        elif df.loc[i]['rsi'] >= 80:
            if is_stock_bought:
                print(f"Closed position at price level: {close_price}! Price range: {close_price - price_bought}, RSI: {df.loc[i]['rsi']}")
                money += int(close_price)
                won += close_price - price_bought
                result.append([i, df.loc[i]['close']])
                is_stock_bought = False
                print(f"Current money {money}")
    
    if is_stock_bought:
        print(f"Closed position! Price range: {close_price - price_bought}")
        money += int(close_price)
        won += close_price - price_bought
        is_stock_bought = False
        
    print(f"End up with {money}!!!")
    
    return result



result = print_rsi_strategy(df)

np1 = np.array([i[0] for i in result])
np2 = np.array([i[1] for i in result])
plt.figure(figsize=(10,10))
plt.tick_params(axis = 'both', labelsize = 10)
plt.plot(df.loc[start_index:]['close'], label="close")
plt.plot(np1, np2, '.', color='red')
plt.show()
# Out:
# Starting with 1000.
# Bought Tesla possition when price level: 686.1483764648438 and RSI: 61.57926604851061
# Current money 307
# Closed position at price level: 690.3800048828125! Price range: 4.23162841796875, RSI: 84.83776618412966
# Current money 997
# Bought Tesla possition when price level: 691.22998046875 and RSI: 68.16663731790086
# Current money 299
# Closed position at price level: 662.2999877929688! Price range: -28.92999267578125, RSI: 81.58158704183523
# Current money 961
# Bought Tesla possition when price level: 661.7628173828125 and RSI: 66.32850611101631
# Current money 293
# Closed position at price level: 638.7382202148438! Price range: -23.02459716796875, RSI: 81.81313676791909
# Current money 931
# Bought Tesla possition when price level: 643.3900146484375 and RSI: 67.11827758435315
# Current money 282
# Closed position at price level: 613.5466918945312! Price range: -29.84332275390625, RSI: 81.80989155947508
# Current money 895
# Bought Tesla possition when price level: 627.6400146484375 and RSI: 67.64039252225871
# Current money 262
# Closed position at price level: 627.4844970703125! Price range: -0.155517578125, RSI: 83.86996981681061
# Current money 889
# Bought Tesla possition when price level: 650.260009765625 and RSI: 67.25674873799986
# Current money 233
# Closed position at price level: 662.6093139648438! Price range: 12.34930419921875, RSI: 80.43162376963218
# Current money 895
# Bought Tesla possition when price level: 663.2949829101562 and RSI: 65.70519441454567
# Current money 226
# Closed position at price level: 669.3049926757812! Price range: 6.010009765625, RSI: 86.44580954727492
# Current money 895
# Bought Tesla possition when price level: 669.5549926757812 and RSI: 64.40061305330562
# Current money 219
# Closed position at price level: 661.3300170898438! Price range: -8.2249755859375, RSI: 80.99423086719533
# Current money 880
# Bought Tesla possition when price level: 692.3499755859375 and RSI: 68.60041755570826
# Current money 181
# Closed position at price level: 697.2777709960938! Price range: 4.92779541015625, RSI: 85.22945619384294
# Current money 878
# Bought Tesla possition when price level: 703.024169921875 and RSI: 67.54320569298542
# Current money 168
# Closed position at price level: 679.625! Price range: -23.399169921875, RSI: 80.06683842242509
# Current money 847
# Bought Tesla possition when price level: 685.989990234375 and RSI: 69.40383375627471
# Current money 155
# Closed position at price level: 683.7150268554688! Price range: -2.27496337890625, RSI: 82.42172417171409
# Current money 838
# Bought Tesla possition when price level: 698.8200073242188 and RSI: 69.73331060096073
# Current money 133
# Closed position at price level: 701.6300048828125! Price range: 2.80999755859375, RSI: 84.34947285112638
# Current money 834
# Bought Tesla possition when price level: 739.6300048828125 and RSI: 61.82044257210529
# Current money 87
# Closed position at price level: 747.8800048828125! Price range: 8.25, RSI: 89.04577657163841
# Current money 834
# Bought Tesla possition when price level: 761.4190063476562 and RSI: 65.67237426290727
# Current money 65
# Closed position at price level: 764.3900146484375! Price range: 2.97100830078125, RSI: 82.80320502624463
# Current money 829
# Bought Tesla possition when price level: 775.9799194335938 and RSI: 64.51571945126832
# Current money 46
# Closed position at price level: 739.1651000976562! Price range: -36.8148193359375, RSI: 86.18418678503122
# Current money 785
# Bought Tesla possition when price level: 745.1199951171875 and RSI: 69.84358050837508
# Current money 33
# Closed position at price level: 722.1400146484375! Price range: -22.97998046875, RSI: 81.09729107075832
# Current money 755
# Bought Tesla possition when price level: 719.8200073242188 and RSI: 61.088325715529436
# Current money 28
# Closed position at price level: 716.6345825195312! Price range: -3.1854248046875, RSI: 85.39860186865631
# Current money 744
# Bought Tesla possition when price level: 728.239990234375 and RSI: 63.56940460819909
# Current money 9
# Closed position at price level: 738.5499877929688! Price range: 10.30999755859375, RSI: 90.02603232554257
# Current money 747
# End up with 747!!!
