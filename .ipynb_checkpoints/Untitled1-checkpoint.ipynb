# %%
# %matplotlib inline
import pandas
import datetime
import pytz
import os
import time
import mysql.connector as mysql
import matplotlib.pyplot as plt
import numpy as np

def get_curr_date():
    my_timestamp = datetime.datetime.now()

    old_timezone = pytz.timezone("EET")
    new_timezone = pytz.timezone("US/Eastern")

    localized_timestamp = old_timezone.localize(my_timestamp)
    new_timezone_timestamp = localized_timestamp.astimezone(new_timezone)

    return new_timezone_timestamp.strftime("%Y, %-m, %-d, %-H, %-M")


def convert_to_dataframe(data: list):
    df = pandas.DataFrame(data)
    df.transpose()

    df.columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'dividends', 'stocksplits']
    return df

def add_two_moving_averages(df, first_period: int, second_period: int, moving_average_template: str):
    if first_period > 0 and second_period > 0:
        df[moving_average_template+str(first_period)] = df['close'].rolling(window=first_period).mean()
        df[moving_average_template+str(second_period)] = df['close'].rolling(window=second_period).mean()
    else:
        print("Periods for moving averages have to be more than 0")

def add_two_exponential_moving_averages(df, first_period: int, second_period: int, moving_average_template: str):
    if first_period > 0 and second_period > 0:
        df[moving_average_template+str(first_period)] = df['close'].ewm(span = first_period, adjust = False).mean()
        df[moving_average_template+str(second_period)] = df['close'].ewm(span = second_period, adjust = False).mean()
    else:
        print("Periods for moving averages have to be more than 0")        
        

db = mysql.connect(
    host = "localhost",
    user = "root",
    passwd = "Asdf123er!",
    auth_plugin='mysql_native_password',
    database = "borader"
)

cursor = db.cursor()

query = "SELECT * from myFinalTable"

cursor.execute(query)
data = cursor.fetchall()

# Transforming data(list) to dataframe
# Dataframe has more options for making trading strategies
#like creating moving averages in one line of code

#print(convert_to_dataframe(data))
def get_buy_sell_decision(df, strategy_label_one, strategy_label_two):
    #TODO Exeption if strategy_labels aren't matching
    
    df['signal'] = 0.0  
    df['signal'] = np.where(df[strategy_label_one] > df[strategy_label_two], 1.0, 0.0) 

    # Get the difference between element-to element
    # That way you can track when xMA is crossing yMA
    # When xMA pass over yMA - buy
    # When xMA pass under yMA - sell
    df['position'] = df['signal'].diff()

"""
def from_datetime_to_int(dt: datetime):
    new_date = dt[dt.index(" ") + 1: dt.index(" ") + 6]
    res = new_date.replace(':','')
    return int(res)

def get_x_ticks(df, start_index: int, ticks: int):
    result = []
    end_index = len(df) - 1
    sum_index = end_index - start_index + 1
    tick = int(sum_index / ticks)
    for i in range(ticks - 1):
        tmp = str(df.loc[start_index + tick * i] ['timestamp'])
        result.append(from_datetime_to_int(tmp))
        
    tmp = str(df.loc[end_index] ['timestamp'])
    result.append(from_datetime_to_int(tmp))
    return result
    
"""

def print_results_from_strategy(df, start_index: int):
    # This is dumb but for now works
    is_stock_bought = False
    price_bought = 0
    is_stock_sold = False
    price_sold = 0
    won = 0
    close_price = 0
    for i in range(start_index, len(df)):
        close_price = df.loc[i]['close']
        if df.loc[i]['position'] == 1:
            if is_stock_sold:
                print(f"Closed position at price level: {close_price}! Price range: {price_sold - close_price}")
                won += price_sold - close_price
                is_stock_sold = False
            print(f"Bought Tesla possition when price level: {close_price}")
            price_bought = close_price
            is_stock_bought = True
        elif df.loc[i]['position'] == -1:
            if is_stock_bought:
                print(f"Closed position at price level: {close_price}! Price range: {close_price - price_bought}")
                won += close_price - price_bought
                is_stock_bought = False
            print(f"Sold Tesla position when price level: {close_price}")
            is_stock_sold = True
            price_sold = close_price

    if is_stock_sold:
        print(f"Closed position! Price range: {price_sold - close_price}")
        won += price_sold - close_price
        is_stock_sold = False
    
    if is_stock_bought:
        print(f"Closed position! Price range: {close_price - price_bought}")
        won += close_price - price_bought
        is_stock_bought = False
    return won
                            

period_one = 50 # 30 for the win - EMA: 50 for the win 
period_two = 200 # 60 for the win - EMA:
"""moving_average_template = "SMA"
add_two_moving_averages(df, period_one, period_two, moving_average_template)

ma_one = moving_average_template+str(period_one)
ma_two = moving_average_template+str(period_two)

get_buy_sell_decision(df, ma_one, ma_two)"""

moving_average_template = "EMA"
add_two_exponential_moving_averages(df, period_one, period_two, moving_average_template)
ma_one = moving_average_template+str(period_one)
ma_two = moving_average_template+str(period_two)

get_buy_sell_decision(df, ma_one, ma_two)

"""df.drop('dividends', axis=1, inplace=True)
df.drop('stocksplits', axis=1, inplace=True)"""

print(df)

start_index = 2

print(print_results_from_strategy(df, start_index))

plt.figure(figsize=(20,20))
plt.tick_params(axis = 'both', labelsize = 10)
plt.plot(df.loc[start_index:]['close'], label="close")
"""plt.plot(df.loc[900:][ma_label_one], 'g--', label=ma_label_one)
plt.plot(df.loc[900:][ma_label_two], 'r--', label=ma_label_two)"""

# After visualizing ma and ema :
# Results: EMA is more accurate and will potentially win more money
plt.plot(df.loc[start_index:][ma_one], 'y--', label=ma_one)
plt.plot(df.loc[start_index:][ma_two], 'b--', label=ma_two)

# Plot buy signals
plt.plot(df.loc[start_index:][df.loc[start_index:]['position'] == 1].index, 
         df.loc[start_index:][ma_one][df.loc[start_index:]['position'] == 1], 
         '.', markersize = 10, color = 'g', label = 'buy')
# Plot sell signals
plt.plot(df.loc[start_index:][df.loc[start_index:]['position'] == -1].index, 
         df.loc[start_index:][ma_one][df.loc[start_index:]['position'] == -1], 
         '.', markersize = 10, color = 'r', label = 'sell')

plt.legend()
plt.xlabel("date")
plt.ylabel("$ price")
plt.grid()
plt.show()

df.drop(ma_one, axis=1, inplace=True)
df.drop(ma_two, axis=1, inplace=True)
# Out:
#                timestamp        open        high         low       close  \
# 0    2021-03-22 09:30:00  685.299988  685.900024  685.299988  685.880005
# 1    2021-03-22 09:31:00  685.979980  687.309998  682.890015  687.309998
# 2    2021-03-22 09:32:00  687.010010  692.880005  686.824707  691.205627
# 3    2021-03-22 09:33:00  691.020020  694.159973  689.690002  693.969971
# 4    2021-03-22 09:34:00  693.859985  694.419983  691.000000  691.000000
# ...                  ...         ...         ...         ...         ...
# 1164 2021-03-24 15:55:00  632.280029  632.400024  631.104980  631.735291
# 1165 2021-03-24 15:56:00  631.739990  632.349976  631.266602  632.205017
# 1166 2021-03-24 15:57:00  632.224976  632.450012  631.510010  632.200012
# 1167 2021-03-24 15:58:00  632.200012  632.380005  631.429993  631.659912
# 1168 2021-03-24 15:59:00  631.380127  631.639893  630.109985  630.119995
#
#        volume  signal  position       EMA10       EMA50
# 0     2103074     0.0       NaN  685.880005  685.880005
# 1      288975     1.0       1.0  686.140004  685.936083
# 2      516941     1.0       0.0  687.061026  686.142732
# 3      364320     1.0       0.0  688.317198  686.449682
# 4      244007     1.0       0.0  688.804980  686.628126
# ...       ...     ...       ...         ...         ...
# 1164   157613     0.0       0.0  632.632818  634.698201
# 1165   135321     0.0       0.0  632.555036  634.600429
# 1166   100025     0.0       0.0  632.490486  634.506295
# 1167   112900     0.0       0.0  632.339473  634.394672
# 1168   249284     0.0       0.0  631.935931  634.227038
#
# [1169 rows x 10 columns]
# Sold Tesla position when price level: 684.4949951171875
# Closed position at price level: 682.9871826171875! Price range: 1.5078125
# Bought Tesla possition when price level: 682.9871826171875
# Closed position at price level: 688.5! Price range: 5.5128173828125
# Sold Tesla position when price level: 688.5
# Closed position at price level: 691.4224853515625! Price range: -2.9224853515625
# Bought Tesla possition when price level: 691.4224853515625
# Closed position at price level: 695.5599975585938! Price range: 4.13751220703125
# Sold Tesla position when price level: 695.5599975585938
# Closed position at price level: 694.480224609375! Price range: 1.07977294921875
# Bought Tesla possition when price level: 694.480224609375
# Closed position at price level: 692.7849731445312! Price range: -1.69525146484375
# Sold Tesla position when price level: 692.7849731445312
# Closed position at price level: 692.330078125! Price range: 0.45489501953125
# Bought Tesla possition when price level: 692.330078125
# Closed position at price level: 690.3682250976562! Price range: -1.96185302734375
# Sold Tesla position when price level: 690.3682250976562
# Closed position at price level: 675.739990234375! Price range: 14.62823486328125
# Bought Tesla possition when price level: 675.739990234375
# Closed position at price level: 670.5330200195312! Price range: -5.20697021484375
# Sold Tesla position when price level: 670.5330200195312
# Closed position at price level: 671.97998046875! Price range: -1.44696044921875
# Bought Tesla possition when price level: 671.97998046875
# Closed position at price level: 671.0100708007812! Price range: -0.96990966796875
# Sold Tesla position when price level: 671.0100708007812
# Closed position at price level: 672.1508178710938! Price range: -1.1407470703125
# Bought Tesla possition when price level: 672.1508178710938
# Closed position at price level: 668.0999755859375! Price range: -4.05084228515625
# Sold Tesla position when price level: 668.0999755859375
# Closed position at price level: 668.6663208007812! Price range: -0.56634521484375
# Bought Tesla possition when price level: 668.6663208007812
# Closed position at price level: 669.8400268554688! Price range: 1.1737060546875
# Sold Tesla position when price level: 669.8400268554688
# Closed position at price level: 668.22998046875! Price range: 1.61004638671875
# Bought Tesla possition when price level: 668.22998046875
# Closed position at price level: 667.1300048828125! Price range: -1.0999755859375
# Sold Tesla position when price level: 667.1300048828125
# Closed position at price level: 668.7000122070312! Price range: -1.57000732421875
# Bought Tesla possition when price level: 668.7000122070312
# Closed position at price level: 666.5999755859375! Price range: -2.10003662109375
# Sold Tesla position when price level: 666.5999755859375
# Closed position at price level: 662.4749755859375! Price range: 4.125
# Bought Tesla possition when price level: 662.4749755859375
# Closed position at price level: 660.0! Price range: -2.4749755859375
# Sold Tesla position when price level: 660.0
# Closed position at price level: 655.52001953125! Price range: 4.47998046875
# Bought Tesla possition when price level: 655.52001953125
# Closed position at price level: 655.1005859375! Price range: -0.41943359375
# Sold Tesla position when price level: 655.1005859375
# Closed position at price level: 657.1900024414062! Price range: -2.08941650390625
# Bought Tesla possition when price level: 657.1900024414062
# Closed position at price level: 660.3300170898438! Price range: 3.1400146484375
# Sold Tesla position when price level: 660.3300170898438
# Closed position at price level: 647.780029296875! Price range: 12.54998779296875
# Bought Tesla possition when price level: 647.780029296875
# Closed position at price level: 646.9400024414062! Price range: -0.84002685546875
# Sold Tesla position when price level: 646.9400024414062
# Closed position at price level: 649.6699829101562! Price range: -2.72998046875
# Bought Tesla possition when price level: 649.6699829101562
# Closed position at price level: 646.2606811523438! Price range: -3.4093017578125
# Sold Tesla position when price level: 646.2606811523438
# Closed position! Price range: 16.14068603515625
# 33.845947265625
